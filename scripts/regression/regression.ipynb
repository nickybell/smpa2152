# %% [markdown]
# # Regression

# %% [markdown]
# Before we get started, let's install and load the packages and data we will be using today. I am also including a little bit of code that is optional, but will speed up installing packages *dramatically*.

# %%
options(repos = c(CRAN = "https://packagemanager.posit.co/cran/latest"))
install.packages("tidyverse")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(tidyverse)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.2.0     ✔ readr     2.2.0
# ✔ forcats   1.0.1     ✔ stringr   1.6.0
# ✔ ggplot2   4.0.2     ✔ tibble    3.3.1
# ✔ lubridate 1.9.5     ✔ tidyr     1.3.2
# ✔ purrr     1.2.1
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %% [markdown]
# Today, we will be working with the replication dataset for De Sante's (2013) experiment examining how people choose to allocate social benefits according to ideas about "deservingness."

# %%
desante <- read_csv("desante2013_modified.csv")
# Out:
# Rows: 2000 Columns: 10
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (4): race, work_ethic, pid, gender
# dbl (6): respondent_id, treatment, allocation, bal_bud, age, income_1000s
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
reg2 <- lm(allocation ~ income_1000s, data = desante)
summary(reg2)
# Out:
# Call:
# lm(formula = allocation ~ income_1000s, data = desante)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -600.92  -90.11   67.20  169.76  367.20
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  605.7876    11.6397  52.045  < 2e-16 ***
# income_1000s  -0.4866     0.1505  -3.233  0.00125 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 253.9 on 1776 degrees of freedom
#   (222 observations deleted due to missingness)
# Multiple R-squared:  0.005852,	Adjusted R-squared:  0.005292
# F-statistic: 10.45 on 1 and 1776 DF,  p-value: 0.001246

# %%
reg3 <- lm(allocation ~ race + work_ethic + age + gender + pid + income_1000s, data = desante)
summary(reg3)
# Out:
# Call:
# lm(formula = allocation ~ race + work_ethic + age + gender +
#     pid + income_1000s, data = desante)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -745.77 -139.11   47.72  188.73  559.09
#
# Coefficients:
#                 Estimate Std. Error t value Pr(>|t|)
# (Intercept)     799.7902    46.1908  17.315  < 2e-16 ***
# racewhite        48.3127    19.8182   2.438   0.0150 *
# work_ethicpoor -152.9050    19.7558  -7.740 3.72e-14 ***
# age              -0.9303     0.7483  -1.243   0.2142
# genderMale      -29.5499    20.8334  -1.418   0.1565
# pidIndependent  -80.8956    31.3644  -2.579   0.0101 *
# pidRepublican  -123.3016    21.6275  -5.701 1.79e-08 ***
# income_1000s     -0.6425     0.2523  -2.547   0.0111 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 255.9 on 664 degrees of freedom
#   (1328 observations deleted due to missingness)
# Multiple R-squared:  0.1487,	Adjusted R-squared:  0.1397
# F-statistic: 16.57 on 7 and 664 DF,  p-value: < 2.2e-16

# %% [markdown]
# Let's look at the error.

# %%
desante$prediction <- predict(reg3, desante)
desante$error <- desante$allocation-desante$prediction
desante |>
  select(allocation, prediction, error, race, work_ethic, pid, age, gender, income_1000s) |>
  slice_max(abs(error), n = 10)
# Out:
#      allocation prediction error     race  work_ethic pid         age gender
# 1202 0          745.7728   -745.7728 black excellent  Democrat    49  Female
# 1012 0          709.5029   -709.5029 black excellent  Democrat    58  Female
# 437  0          679.9465   -679.9465 white excellent  Independent 78  Female
# 554  0          621.4406   -621.4406 black excellent  Independent 44  Male
# 899  0          611.5013   -611.5013 white excellent  Republican  58  Male
# 1481 0          607.0535   -607.0535 black excellent  Republican  51  Female
# 1011 0          604.9107   -604.9107 white poor       Democrat    58  Female
# 1051 0          604.4751   -604.4751 white excellent  Republican  63  Male
# 198  0          602.2274   -602.2274 black excellent  Democrat    77  Male
# 372  0          598.3216   -598.3216 white excellent  Republican  64  Male
#      income_1000s
# 1202  13.126
# 1012  56.543
# 437   22.877
# 554   41.977
# 899   46.369
# 1481  34.225
# 1011  56.543
# 1051  50.065
# 198  150.000
# 372   58.194
